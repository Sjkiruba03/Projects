# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjust the configuration of the plot we create

# %%
# Read the Data
df = pd.read_csv(r'C:\Users\KIRUBAK\Downloads\movies correlation.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
# Let's see if there any missing value
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print( ' {} -  {}'.format(col,pct_missing))
# Out:
#  name -  0.0
#  rating -  0.010041731872717789
#  genre -  0.0
#  year -  0.0
#  released -  0.0002608242044861763
#  score -  0.0003912363067292645
#  votes -  0.0003912363067292645
#  director -  0.0
#  writer -  0.0003912363067292645
#  star -  0.00013041210224308815
#  country -  0.0003912363067292645
#  budget -  0.2831246739697444
#  gross -  0.02464788732394366
#  company -  0.002217005738132499
#  runtime -  0.0005216484089723526

# %%
df.shape
# Out:
# (7668, 15)

# %%
# This commend used to drop the rows thta has an null values in it
data = df.dropna()

# %%
data.shape
# Out:
# (5421, 15)

# %%
# Check the datatypes of each column
data.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# change the datatypes of column

data['budget'] = data['budget'].astype(dtype = "int64")

data['gross'] = data['gross'].astype(dtype = "int64")
# Out:
# C:\Users\KIRUBAK\AppData\Local\Temp\ipykernel_22396\1474892863.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['budget'] = data['budget'].astype(dtype = "int64")
# C:\Users\KIRUBAK\AppData\Local\Temp\ipykernel_22396\1474892863.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['gross'] = data['gross'].astype(dtype = "int64")

# %%
data['gross'].dtype
# Out:
# dtype('int64')

# %%
data['released'][0]
# Out:
# 'June 13, 1980 (United States)'

# %%
# create correct year column
data['yearcorrect'] = data['released'].str.extract(pat ='([0-9]{4})').astype("int")
# Out:
# C:\Users\KIRUBAK\AppData\Local\Temp\ipykernel_22396\48616170.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['yearcorrect'] = data['released'].str.extract(pat ='([0-9]{4})').astype("int")

# %%
data['yearcorrect']
# Out:
# 0       1980
# 1       1980
# 2       1980
# 3       1980
# 4       1980
#         ...
# 7648    2020
# 7649    2020
# 7650    2020
# 7651    2020
# 7652    2020
# Name: yearcorrect, Length: 5421, dtype: int32

# %%
# sort the dataset by gross value
data.sort_values(by = ['gross'],inplace = False,ascending = False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
# to see all the rows of the dataset
pd.set_option('display.max_rows', 20)

# %%
# to check duplicates
data['company'].duplicated().sum()
# Out:
# 3946

# %%
# BUdget High Correlation
# company High Correlation

# %%
# Scatter plot with budget vs Gross
plt.figure(figsize = (20,8))
plt.scatter(x= data['gross'],
            y = data['budget'])
plt.title("Correlation between the Budget and Gross of film", fontsize = 16)
plt.ylabel("Budget of the film")
plt.xlabel("Gross Revenue of the film")
plt.show()

# %%
# plot budget vs gross using seaborn
# to check the diff use diff color for line and scatter
sns.regplot(data = data, x = "gross", y = "budget", scatter_kws = {"color": "red"}, line_kws = {"color":"blue"})
# Out:
# <Axes: xlabel='gross', ylabel='budget'>

# %%
# Let's start looking at correlation

# %%
# There are diff types of corr default is pearson, and # kendall , spearman are there as well
data.corr(numeric_only = True)
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score        0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes        0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget       0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross        0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime      0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# yearcorrect  0.998726  0.061923  0.203098  0.320312  0.268721  0.075294
#
#              yearcorrect
# year            0.998726
# score           0.061923
# votes           0.203098
# budget          0.320312
# gross           0.268721
# runtime         0.075294
# yearcorrect     1.000000

# %%
corr_matrix = data.corr(numeric_only = True)

# %%
# Let's see in heatmap

sns.heatmap(corr_matrix, annot = True)

plt.title("Correlation Matrix")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
plt.show()

# %%
# Let's see country
data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Change the string into numeric value to check the correlation of those

df_num = data.copy()

for col in df_num.columns:
    if df_num[col].dtype == 'object':
        df_num[col] = df_num[col].astype(dtype = "category")
        df_num[col] = df_num[col].cat.codes

df_num.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country    budget      gross  company  runtime  yearcorrect
# 0   699       46  19000000   46998772     1426    146.0         1980
# 1   214       47   4500000   58853106      452    104.0         1980
# 2  1157       47  18000000  538375067      945    124.0         1980
# 3  1474       47   3500000   83453539     1108     88.0         1980
# 4   271       47   6000000   39846344     1083     98.0         1980

# %%
data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
corr_matrix = df_num.corr(numeric_only = True)

sns.heatmap(corr_matrix, annot = True)

plt.title("Correlation Matrix")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
plt.show()

# %%
# For btter view we use unstack funtion

df_corr_matrix = df_num.corr()
corr_pairs = df_corr_matrix.unstack()

corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released      -0.006152
#                               ...
# yearcorrect  budget         0.320312
#              gross          0.268721
#              company       -0.018806
#              runtime        0.075294
#              yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
sorted_pair = corr_pairs.sort_values()
sorted_pair
# Out:
# genre        budget        -0.368523
# budget       genre         -0.368523
# gross        genre         -0.244101
# genre        gross         -0.244101
# rating       budget        -0.203946
#                               ...
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
# to check High correlation
high_corr = sorted_pair[(sorted_pair) > 0.5]
high_corr
# Out:
# gross        votes          0.614751
# votes        gross          0.614751
# gross        budget         0.740247
# budget       gross          0.740247
# year         yearcorrect    0.998726
#                               ...
#              year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 22, dtype: float64

# %%
# Votes and budget have the high correlation

# and company has low correlation
